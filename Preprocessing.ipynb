# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('PreLibBooks.csv')

# %%
df.head(1200)
# Out:
#       S. NO.         NAME OF BOOK AUTHOR LAST NAME AUTHOR FIRST NAME  \
# 0          1  365 BEDTIME STORIES         SPURGEON             NANCY
# 1          2                a b c            HOUSE            WONDER
# 2          3           A BIT LOST         HAUGHTON             CHRIS
# 3          4     A DAY AT THE ZOO             Anon               NaN
# 4          5         A GREAT GAME        SUDHAKAR            SUMATHI
# ...      ...                  ...              ...               ...
# 1195     511         WILD ANIMALS            HOUSE            WONDER
# 1196     512         WILD ANIMALS              NaN               NaN
# 1197     513           YUMMY FOOD       YUMMY FOOD               NaN
# 1198     514         ZIP AND ZOOM             LAMB               AMY
# 1199     515   ZOOM, ZOOM, BABY!               NaN               NaN
#
#               ISBN# YEAR OF PUBLICATION AVAILABILITIY Unnamed: 7
# 0     9780709708698                1969            L         NaN
# ...

# %%
df['S. NO.'] = df.reset_index().index + 1
# Out:
# C:\Users\Tanish\AppData\Local\Temp\ipykernel_9100\790050860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['S. NO.'] = df.reset_index().index + 1

# %%
# Count duplicates and update numCopies column
df['numCopies'] = df.groupby('NAME OF BOOK')['NAME OF BOOK'].transform('count')

# %%
df.sort_values('numCopies', ascending = False)
# Out:
#      S. NO.                           NAME OF BOOK  AUTHOR LAST NAME  \
# 422     423                                NUMBERS               NaN
# 40       41                BUBBLES PLAYS WITH FIRE           BUBBLES
# 292     293                      BUBBLES IS GREEDY           BUBBLES
# 489     490                   THE VERY BUSY SPIDER             CARLE
# 30       31               BUBBLES FINDS A RED BALL           BUBBLES
# ..      ...                                    ...               ...
# 357     358               KING JACK AND THE DRAGON   BENTLY&OXENBURY
# 99      100           KITTENS NEED SOMEONE TO LOVE             HINDS
# 259     260                                  a b c             HOUSE
# 256     257  FAIRY HILL, RUBY AND THE MAGIC GARDEN               NaN
# 257     258                          NAME OF BOOKS  AUTHOR LAST NAME
#
#      AUTHOR FIRST NAME          ISBN#  YEAR OF PUBLICATION  AVAILABILITIY  \
# ...

# %%
df
# Out:
#      S. NO.           NAME OF BOOK AUTHOR LAST NAME AUTHOR FIRST NAME  \
# 0         1    365 BEDTIME STORIES         SPURGEON             NANCY
# 260     261             A BIT LOST         HAUGHTON             CHRIS
# 3         4       A DAY AT THE ZOO             Anon               NaN
# 262     263           A GREAT GAME        SUDHAKAR            SUMATHI
# 5         6  A GREEN, GREEN GARDEN            MAYOR            MERCER
# ..      ...                    ...              ...               ...
# 511     512           WILD ANIMALS              NaN               NaN
# 253     254             YUMMY FOOD       YUMMY FOOD               NaN
# 513     514           ZIP AND ZOOM             LAMB               AMY
# 255     256     ZOOM, ZOOM, BABY!               NaN               NaN
# 259     260                  a b c            HOUSE            WONDER
#
#              ISBN# YEAR OF PUBLICATION  numCopies  AVAILABILITY
# ...

# %%
df.to_csv('cleanedPreLibBooks.csv', index=False)
